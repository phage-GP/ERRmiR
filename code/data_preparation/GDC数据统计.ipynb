# %% [markdown]
# 截至2022年11月10日，GDC中记录了54种初发病位点，包含TCGA、TARGET、CPTAC等六个主要组织，44个项目，32种疾病类型共计14531个案例，16617个isomiRNA测序文件；从中整理到14530个案例，16616个测序文件。
#
# 为了选择满足机器学习任务的数据，我们对GDC数据进行样本类型量统计，44个项目其中28个项目含有Normal的对照组。
#
# | Primary Site | kidney                                                       | bronchus and lung            | bronchus and lung           | thyroid gland                  |
# | ------------ | ------------------------------------------------------------ | ---------------------------- | --------------------------- | ------------------------------ |
# | Disease Type | adenomas and adenocarcinomas                                 | adenomas and adenocarcinomas | squamous cell neoplasms     | adenomas and adenocarcinomas   |
# | Project      | TCGA-KIRC 71     TCGA-KIRP 34     CPTAC-3 148     TCGA-KICH 25 | TCGA-LUAD 46     CPTAC-3 215 | TCGA-LUSC 45     CPTAC-3 96 | TCGA-THCA 59     REBC-THYR 397 |
# | normal 总计  | 278                                                          | 261                          | 141                         | 456                            |

# %%
# !pip install ujson

# %%
import pandas as pd
import seaborn as sns
import ujson

# %%
with open('../../data/GDC/metadata.cart.2022-11-10_part1.json','r',encoding='utf8')as fp:
    part1_json = ujson.load(fp)

with open('../../data/GDC/metadata.cart.2022-11-10_part2.json','r',encoding='utf8')as fp:
    part2_json = ujson.load(fp)

# %% [markdown]
# 数据探索

# %%
len(part1_json)
# Out:
# 9425

# %%
len(part2_json)
# Out:
# 7191

# %%
part1_json[0]
# Out:
# {'data_format': 'TXT',
#  'access': 'open',
#  'associated_entities': [{'entity_submitter_id': 'TCGA-2J-AAB8-01A-12R-A41G-13',
#    'entity_type': 'aliquot',
#    'case_id': '2e8f90f4-aed3-43b0-985c-dfdc2581f24f',
#    'entity_id': 'f2ab8ac5-fed7-4e49-94d2-9c0ed0c56636'}],
#  'file_name': '3e3337e6-c444-4539-8ba8-82ae85a96d15.mirbase21.isoforms.quantification.txt',
#  'submitter_id': 'mirna_swap_dr11_36_MirnaExpression49657465-cd5a-4b03-a349-3f55c26bcb73_isoform_profiling',
#  'data_category': 'Transcriptome Profiling',
#  'analysis': {'input_files': [{'data_format': 'BAM',
#     'access': 'controlled',
#     'file_name': 'TCGA-2J-AAB8-01A-12R-A41G-13_mirna_gdc_realn.bam',
#     'submitter_id': 'mirna_swap_dr11_36_AlignedReads49657465-cd5a-4b03-a349-3f55c26bcb73',
#     'data_category': 'Sequencing Reads',
#     'platform': 'Illumina',
#     'file_size': 245033338,
#     'created_datetime': '2018-03-20T06:38:21.377090-05:00',
#     'md5sum': '94d49b68a6f8b5c1a8d87a07aeea5b2b',
#     'updated_datetime': '2018-11-15T21:47:23.001784-06:00',
#     'file_id': 'c51e04f0-efa6-4694-b865-b5c55afa5004',
#     'data_type': 'Aligned Reads',
#     'state': 'released',
#     'experimental_strategy': 'miRNA-Seq'}],
#   'updated_datetime': '2018-09-10T15:08:41.786316-05:00',
#   'workflow_link': 'https://github.com/NCI-GDC/gdc-dnaseq-cwl/blob/gdc-active-submission/workflows/mirnaseq/runner.cwl',
#   'submitter_id': 'mirna_swap_dr11_36_MirnaExpressionWorkflow8bdc8c28-c966-4346-addf-4abd2a9e2b6b_pipeline:mirnaseq0.0.1',
#   'state': 'released',
#   'workflow_type': 'BCGSC miRNA Profiling',
#   'analysis_id': '1162aad4-ffb8-4350-83e9-fe6d6d6ed1da',
#   'created_datetime': '2018-03-20T06:38:21.377090-05:00'},
#  'file_size': 399215,
#  'md5sum': 'c59be4a170078dc6f51648843ab9dc19',
#  'file_id': '806b9787-2366-4dfe-b053-69267fb3e4fc',
#  'data_type': 'Isoform Expression Quantification',
#  'state': 'released',
#  'experimental_strategy': 'miRNA-Seq'}

# %%
df_part1 = pd.read_csv('../../data/GDC/gdc_sample_sheet.2022-11-10_part1.tsv',sep='\t')
df_part2 = pd.read_csv('../../data/GDC/gdc_sample_sheet.2022-11-10_part2.tsv',sep='\t')

# %%
df_tcga_abbrev = pd.read_excel('../../data/GDC/TCGA_Abbrev.xlsx')
df_tcga_abbrev.head()
# Out:
#   Study Abbreviation                    Study Name
# 0               LAML        Acute Myeloid Leukemia
# 1                ACC      Adrenocortical carcinoma
# 2               BLCA  Bladder Urothelial Carcinoma
# 3                LGG      Brain Lower Grade Glioma
# 4               BRCA     Breast invasive carcinoma

# %%
df_tcga_abbrev['Study Abbreviation'] = 'TCGA-' + df_tcga_abbrev['Study Abbreviation'] 
df_tcga_abbrev.head()
# Out:
#   Study Abbreviation                    Study Name
# 0          TCGA-LAML        Acute Myeloid Leukemia
# 1           TCGA-ACC      Adrenocortical carcinoma
# 2          TCGA-BLCA  Bladder Urothelial Carcinoma
# 3           TCGA-LGG      Brain Lower Grade Glioma
# 4          TCGA-BRCA     Breast invasive carcinoma

# %%
df_sample_sheet = pd.concat([df_part1,df_part2])
print(df_sample_sheet.info())
df_sample_sheet.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16616 entries, 0 to 7190
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   File ID        16616 non-null  object
#  1   File Name      16616 non-null  object
#  2   Data Category  16616 non-null  object
#  3   Data Type      16616 non-null  object
#  4   Project ID     16616 non-null  object
#  5   Case ID        16616 non-null  object
#  6   Sample ID      16616 non-null  object
#  7   Sample Type    16616 non-null  object
# dtypes: object(8)
# memory usage: 1.1+ MB
# None
#                                 File ID  \
# 0  806b9787-2366-4dfe-b053-69267fb3e4fc
# 1  f0d9f59e-06dd-4c16-a31d-37ace1c7edd1
# 2  3f2a4877-473e-4595-bb79-3b6c25219201
# 3  01e18cae-c606-40c2-a1f7-f14063c2b62d
# 4  73dc240c-51ed-43f7-9baf-6c36f12121ef
#
#                                            File Name            Data Category  \
# 0  3e3337e6-c444-4539-8ba8-82ae85a96d15.mirbase21...  Transcriptome Profiling
# 1  3b219bb6-74eb-45b0-ba74-76c475a69d1b.mirbase21...  Transcriptome Profiling
# 2  fa17ecee-b9d7-4305-90f3-8afd3a12f256.mirbase21...  Transcriptome Profiling
# 3  9f056d34-77f0-42a9-9b08-efaaebb2b03c.mirbase21...  Transcriptome Profiling
# 4  2c9272ba-2dd6-46cf-9177-51e7db8eefc7.mirbase21...  Transcriptome Profiling
#
#                            Data Type Project ID       Case ID  \
# 0  Isoform Expression Quantification  TCGA-PAAD  TCGA-2J-AAB8
# 1  Isoform Expression Quantification  TCGA-PAAD  TCGA-HZ-7289
# 2  Isoform Expression Quantification  TCGA-PAAD  TCGA-Z5-AAPL
# 3  Isoform Expression Quantification  TCGA-PAAD  TCGA-2L-AAQI
# 4  Isoform Expression Quantification  TCGA-PAAD  TCGA-HZ-7926
#
#           Sample ID    Sample Type
# 0  TCGA-2J-AAB8-01A  Primary Tumor
# 1  TCGA-HZ-7289-01A  Primary Tumor
# 2  TCGA-Z5-AAPL-01A  Primary Tumor
# 3  TCGA-2L-AAQI-01A  Primary Tumor
# 4  TCGA-HZ-7926-01A  Primary Tumor

# %%
df_sample_sheet  = pd.merge(df_sample_sheet,df_tcga_abbrev,left_on='Project ID',right_on='Study Abbreviation')
df_sample_sheet.head()
# Out:
#                                 File ID  \
# 0  806b9787-2366-4dfe-b053-69267fb3e4fc
# 1  f0d9f59e-06dd-4c16-a31d-37ace1c7edd1
# 2  3f2a4877-473e-4595-bb79-3b6c25219201
# 3  01e18cae-c606-40c2-a1f7-f14063c2b62d
# 4  73dc240c-51ed-43f7-9baf-6c36f12121ef
#
#                                            File Name            Data Category  \
# 0  3e3337e6-c444-4539-8ba8-82ae85a96d15.mirbase21...  Transcriptome Profiling
# 1  3b219bb6-74eb-45b0-ba74-76c475a69d1b.mirbase21...  Transcriptome Profiling
# 2  fa17ecee-b9d7-4305-90f3-8afd3a12f256.mirbase21...  Transcriptome Profiling
# 3  9f056d34-77f0-42a9-9b08-efaaebb2b03c.mirbase21...  Transcriptome Profiling
# 4  2c9272ba-2dd6-46cf-9177-51e7db8eefc7.mirbase21...  Transcriptome Profiling
#
#                            Data Type Project ID       Case ID  \
# 0  Isoform Expression Quantification  TCGA-PAAD  TCGA-2J-AAB8
# 1  Isoform Expression Quantification  TCGA-PAAD  TCGA-HZ-7289
# 2  Isoform Expression Quantification  TCGA-PAAD  TCGA-Z5-AAPL
# 3  Isoform Expression Quantification  TCGA-PAAD  TCGA-2L-AAQI
# 4  Isoform Expression Quantification  TCGA-PAAD  TCGA-HZ-7926
#
#           Sample ID    Sample Type Study Abbreviation  \
# 0  TCGA-2J-AAB8-01A  Primary Tumor          TCGA-PAAD
# 1  TCGA-HZ-7289-01A  Primary Tumor          TCGA-PAAD
# 2  TCGA-Z5-AAPL-01A  Primary Tumor          TCGA-PAAD
# 3  TCGA-2L-AAQI-01A  Primary Tumor          TCGA-PAAD
# 4  TCGA-HZ-7926-01A  Primary Tumor          TCGA-PAAD
#
#                   Study Name
# 0  Pancreatic adenocarcinoma
# 1  Pancreatic adenocarcinoma
# 2  Pancreatic adenocarcinoma
# 3  Pancreatic adenocarcinoma
# 4  Pancreatic adenocarcinoma

# %%
df_platform = pd.read_csv('../../data/GDC/PanCanAtlas_miRNA_sample_information_list.txt',sep='\t')[['id','Platform','Disease']]
print(df_platform.shape)
df_platform.head()
# Out:
# (10824, 3)
#                              id Platform Disease
# 0  TCGA-OR-A5J1-01A-11R-A29W-13    HiSeq     ACC
# 1  TCGA-OR-A5J2-01A-11R-A29W-13    HiSeq     ACC
# 2  TCGA-OR-A5J3-01A-11R-A29W-13    HiSeq     ACC
# 3  TCGA-OR-A5J4-01A-11R-A29W-13    HiSeq     ACC
# 4  TCGA-OR-A5J5-01A-11R-A29W-13    HiSeq     ACC

# %%
'-'.join('TCGA-OR-A5J5-01A-11R-A29W-13'.split('-')[:4])
# Out:
# 'TCGA-OR-A5J5-01A'

# %%
df_platform["new_id"] =['-'.join(i.split('-')[:4]) for i in df_platform["id"]]
df_platform.drop_duplicates(['new_id','Platform'],inplace=True)
df_platform
# Out:
#                                  id Platform Disease            new_id
# 0      TCGA-OR-A5J1-01A-11R-A29W-13    HiSeq     ACC  TCGA-OR-A5J1-01A
# 1      TCGA-OR-A5J2-01A-11R-A29W-13    HiSeq     ACC  TCGA-OR-A5J2-01A
# 2      TCGA-OR-A5J3-01A-11R-A29W-13    HiSeq     ACC  TCGA-OR-A5J3-01A
# 3      TCGA-OR-A5J4-01A-11R-A29W-13    HiSeq     ACC  TCGA-OR-A5J4-01A
# 4      TCGA-OR-A5J5-01A-11R-A29W-13    HiSeq     ACC  TCGA-OR-A5J5-01A
# ...                             ...      ...     ...               ...
# 10819  TCGA-YZ-A980-01A-11R-A40B-13    HiSeq     UVM  TCGA-YZ-A980-01A
# 10820  TCGA-YZ-A982-01A-11R-A40B-13    HiSeq     UVM  TCGA-YZ-A982-01A
# 10821  TCGA-YZ-A983-01A-11R-A40B-13    HiSeq     UVM  TCGA-YZ-A983-01A
# 10822  TCGA-YZ-A984-01A-11R-A40B-13    HiSeq     UVM  TCGA-YZ-A984-01A
# 10823  TCGA-YZ-A985-01A-11R-A40B-13    HiSeq     UVM  TCGA-YZ-A985-01A
#
# [10824 rows x 4 columns]

# %%
df_sample_sheet  = pd.merge(df_sample_sheet,df_platform,left_on='Sample ID',right_on='new_id')
df_sample_sheet.head()
# Out:
#                                 File ID  \
# 0  806b9787-2366-4dfe-b053-69267fb3e4fc
# 1  f0d9f59e-06dd-4c16-a31d-37ace1c7edd1
# 2  3f2a4877-473e-4595-bb79-3b6c25219201
# 3  01e18cae-c606-40c2-a1f7-f14063c2b62d
# 4  73dc240c-51ed-43f7-9baf-6c36f12121ef
#
#                                            File Name            Data Category  \
# 0  3e3337e6-c444-4539-8ba8-82ae85a96d15.mirbase21...  Transcriptome Profiling
# 1  3b219bb6-74eb-45b0-ba74-76c475a69d1b.mirbase21...  Transcriptome Profiling
# 2  fa17ecee-b9d7-4305-90f3-8afd3a12f256.mirbase21...  Transcriptome Profiling
# 3  9f056d34-77f0-42a9-9b08-efaaebb2b03c.mirbase21...  Transcriptome Profiling
# 4  2c9272ba-2dd6-46cf-9177-51e7db8eefc7.mirbase21...  Transcriptome Profiling
#
#                            Data Type Project ID       Case ID  \
# 0  Isoform Expression Quantification  TCGA-PAAD  TCGA-2J-AAB8
# 1  Isoform Expression Quantification  TCGA-PAAD  TCGA-HZ-7289
# 2  Isoform Expression Quantification  TCGA-PAAD  TCGA-Z5-AAPL
# 3  Isoform Expression Quantification  TCGA-PAAD  TCGA-2L-AAQI
# 4  Isoform Expression Quantification  TCGA-PAAD  TCGA-HZ-7926
#
#           Sample ID    Sample Type Study Abbreviation  \
# 0  TCGA-2J-AAB8-01A  Primary Tumor          TCGA-PAAD
# 1  TCGA-HZ-7289-01A  Primary Tumor          TCGA-PAAD
# 2  TCGA-Z5-AAPL-01A  Primary Tumor          TCGA-PAAD
# 3  TCGA-2L-AAQI-01A  Primary Tumor          TCGA-PAAD
# 4  TCGA-HZ-7926-01A  Primary Tumor          TCGA-PAAD
#
#                   Study Name                            id Platform Disease  \
# 0  Pancreatic adenocarcinoma  TCGA-2J-AAB8-01A-12R-A41G-13    HiSeq    PAAD
# 1  Pancreatic adenocarcinoma  TCGA-HZ-7289-01A-11R-2155-13    HiSeq    PAAD
# 2  Pancreatic adenocarcinoma  TCGA-Z5-AAPL-01A-12R-A41G-13    HiSeq    PAAD
# 3  Pancreatic adenocarcinoma  TCGA-2L-AAQI-01A-12R-A39J-13    HiSeq    PAAD
# 4  Pancreatic adenocarcinoma  TCGA-HZ-7926-01A-11R-2155-13    HiSeq    PAAD
#
#              new_id
# 0  TCGA-2J-AAB8-01A
# 1  TCGA-HZ-7289-01A
# 2  TCGA-Z5-AAPL-01A
# 3  TCGA-2L-AAQI-01A
# 4  TCGA-HZ-7926-01A

# %%
df_sample_sheet.loc[df_sample_sheet['Sample Type'].str.contains('Primary Tumor'),'Sample Type'] = 'Primary Tumor'
df_sample_sheet.loc[df_sample_sheet['Sample Type'].str.contains('Solid Tissue Normal'),'Sample Type'] = 'Solid Tissue Normal'

# %% [markdown]
# 样本类型分布

# %%
df_sample_sheet['Sample Type'].value_counts()
# Out:
# Primary Tumor                                      9611
# Solid Tissue Normal                                 658
# Metastatic                                          379
# Primary Blood Derived Cancer - Peripheral Blood     188
# Recurrent Tumor                                      37
# Additional - New Primary                             11
# Additional Metastatic                                 1
# Name: Sample Type, dtype: int64

# %%
sum(df_sample_sheet['Sample Type'].value_counts().index.str.contains('Normal'))
# Out:
# 1

# %%
df_sample_sheet['Sample Type'].value_counts().loc[df_sample_sheet['Sample Type'].value_counts().index.str.contains('Normal')]
# Out:
# Solid Tissue Normal    658
# Name: Sample Type, dtype: int64

# %% [markdown]
# **生成表单**

# %%
df_sample_sheet.loc[(df_sample_sheet['Project ID']=='TCGA-LUAD')&(df_sample_sheet['Sample Type']=='Solid Tissue Normal')].shape
# Out:
# (45, 14)

# %%
df_sample_sheet.loc[df_sample_sheet['Project ID']=='TCGA-LUAD','Study Name'].values[0]
# Out:
# 'Lung adenocarcinoma'

# %%
df_stats = pd.DataFrame(columns=['研究名称','Primary Tumor','Solid Tissue Normal','Hiseq','GA'])

# %%
for project in set(df_sample_sheet['Project ID']):
    if df_sample_sheet.loc[df_sample_sheet['Project ID']==project,'Study Name'].values[0]:
        abbrev = df_sample_sheet.loc[df_sample_sheet['Project ID']==project,'Study Name'].values[0]
    else:
        abbrev = ' '
    print(abbrev)
    num_tumor = df_sample_sheet.loc[(df_sample_sheet['Project ID']==project)&(df_sample_sheet['Sample Type']=='Primary Tumor')].shape[0]
    num_normal = df_sample_sheet.loc[(df_sample_sheet['Project ID']==project)&(df_sample_sheet['Sample Type']=='Solid Tissue Normal')].shape[0]
    num_hiseq = df_sample_sheet.loc[(df_sample_sheet['Project ID']==project)&(df_sample_sheet['Platform']=='HiSeq')].shape[0]
    num_ga = df_sample_sheet.loc[(df_sample_sheet['Project ID']==project)&(df_sample_sheet['Platform']=='GA')].shape[0]
    
    df_stats.loc[project] = [abbrev,num_tumor,num_normal,num_hiseq,num_ga]
    
    # df_stats.append({'项目': project, 'Primary Tumor': num_tumor, 'Solid Tissue Normal': num_normal,'Hiseq':num_hiseq,'GA':num_ga}, ignore_index=True)
# Out:
# Head and Neck squamous cell carcinoma
# Lymphoid Neoplasm Diffuse Large B-cell Lymphoma
# Pheochromocytoma and Paraganglioma
# Uterine Corpus Endometrial Carcinoma
# Kidney renal clear cell carcinoma
# Glioblastoma multiforme
# Colon adenocarcinoma
# Cervical squamous cell carcinoma and endocervical adenocarcinoma
# Lung squamous cell carcinoma
# Cholangiocarcinoma
# Skin Cutaneous Melanoma
# Brain Lower Grade Glioma
# Lung adenocarcinoma
# Liver hepatocellular carcinoma
# Pancreatic adenocarcinoma
# Esophageal carcinoma
# Adrenocortical carcinoma
# Bladder Urothelial Carcinoma
# Stomach adenocarcinoma
# Acute Myeloid Leukemia
# Breast invasive carcinoma
# Kidney Chromophobe
# Ovarian serous cystadenocarcinoma
# Mesothelioma
# Prostate adenocarcinoma
# Rectum adenocarcinoma
# Testicular Germ Cell Tumors
# Sarcoma
# Thyroid carcinoma
# Thymoma
# Uveal Melanoma
# Uterine Carcinosarcoma
# Kidney renal papillary cell carcinoma

# %%
df_stats.to_csv('../../data/GDC/TCGA_miRNA_sample_information_list.tsv',sep='\t')# ,encoding='gb2312'
df_stats
# Out:
#                                                         研究名称  Primary Tumor  \
# TCGA-HNSC              Head and Neck squamous cell carcinoma            519
# TCGA-DLBC    Lymphoid Neoplasm Diffuse Large B-cell Lymphoma             47
# TCGA-PCPG                 Pheochromocytoma and Paraganglioma            178
# TCGA-UCEC               Uterine Corpus Endometrial Carcinoma            527
# TCGA-KIRC                  Kidney renal clear cell carcinoma            523
# TCGA-GBM                             Glioblastoma multiforme              0
# TCGA-COAD                               Colon adenocarcinoma            425
# TCGA-CESC  Cervical squamous cell carcinoma and endocervi...            306
# TCGA-LUSC                       Lung squamous cell carcinoma            467
# TCGA-CHOL                                 Cholangiocarcinoma             36
# TCGA-SKCM                            Skin Cutaneous Melanoma             97
# TCGA-LGG                            Brain Lower Grade Glioma            510
# TCGA-LUAD                                Lung adenocarcinoma            510
# TCGA-LIHC                     Liver hepatocellular carcinoma            369
# TCGA-PAAD                          Pancreatic adenocarcinoma            177
# TCGA-ESCA                               Esophageal carcinoma            184
# TCGA-ACC                            Adrenocortical carcinoma             79
# TCGA-BLCA                       Bladder Urothelial Carcinoma            414
# TCGA-STAD                             Stomach adenocarcinoma            443
# TCGA-LAML                             Acute Myeloid Leukemia              0
# TCGA-BRCA                          Breast invasive carcinoma           1073
# TCGA-KICH                                 Kidney Chromophobe             65
# TCGA-OV                    Ovarian serous cystadenocarcinoma            478
# TCGA-MESO                                       Mesothelioma             87
# TCGA-PRAD                            Prostate adenocarcinoma            491
# TCGA-READ                              Rectum adenocarcinoma            153
# TCGA-TGCT                        Testicular Germ Cell Tumors            149
# TCGA-SARC                                            Sarcoma            256
# TCGA-THCA                                  Thyroid carcinoma            502
# TCGA-THYM                                            Thymoma            124
# TCGA-UVM                                      Uveal Melanoma             80
# TCGA-UCS                              Uterine Carcinosarcoma             56
# TCGA-KIRP              Kidney renal papillary cell carcinoma            286
#
#            Solid Tissue Normal  Hiseq   GA
# TCGA-HNSC                   44    529   36
# TCGA-DLBC                    0     47    0
# TCGA-PCPG                    3    186    0
# TCGA-UCEC                   32    433  127
# TCGA-KIRC                   70    314  280
# TCGA-GBM                     5      5    0
# TCGA-COAD                    8    265  170
# TCGA-CESC                    3    311    0
# TCGA-LUSC                   44    380  131
# TCGA-CHOL                    9     45    0
# TCGA-SKCM                    2    452    0
# TCGA-LGG                     0    528    0
# TCGA-LUAD                   45    497   60
# TCGA-LIHC                   49    421    0
# TCGA-PAAD                    4    182    0
# TCGA-ESCA                   12    197    0
# TCGA-ACC                     0     79    0
# TCGA-BLCA                   19    434    0
# TCGA-STAD                   45    442   46
# TCGA-LAML                    0      0  188
# TCGA-BRCA                   90    836  334
# TCGA-KICH                   24     89    0
# TCGA-OV                      0    487    0
# TCGA-MESO                    0     87    0
# TCGA-PRAD                   52    544    0
# TCGA-READ                    3     92   64
# TCGA-TGCT                    0    155    0
# TCGA-SARC                    0    260    0
# TCGA-THCA                   59    569    0
# TCGA-THYM                    2    126    0
# TCGA-UVM                     0     80    0
# TCGA-UCS                     0     56    0
# TCGA-KIRP                   34    321    0

# %%
for project in set(df_sample_sheet['Project ID']):
    print('#'*20)
    print(f'{project}')
    print('#'*20)
    print(df_sample_sheet.loc[df_sample_sheet['Project ID']==project]['Sample Type'].value_counts())
    print('\n')
# Out:
# ####################
# TARGET-ALL-P3
# ####################
# Primary Blood Derived Cancer - Bone Marrow         28
# Recurrent Blood Derived Cancer - Bone Marrow        7
# Primary Blood Derived Cancer - Peripheral Blood     4
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-ACC
# ####################
# Primary Tumor    80
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-BLCA
# ####################
# Primary Tumor          417
# Solid Tissue Normal     19
# Metastatic               1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-CESC
# ####################
# Primary Tumor          307
# Solid Tissue Normal      3
# Metastatic               2
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-KIRP
# ####################
# Primary Tumor               291
# Solid Tissue Normal          34
# Additional - New Primary      1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-LGG
# ####################
# Primary Tumor      512
# Recurrent Tumor     18
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-THCA
# ####################
# Primary Tumor          506
# Solid Tissue Normal     59
# Metastatic               8
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-KICH
# ####################
# Primary Tumor          66
# Solid Tissue Normal    25
# Name: Sample Type, dtype: int64
#
#
# ####################
# MP2PRT-WT
# ####################
# Metastatic         30
# Recurrent Tumor    23
# Primary Tumor      12
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-SKCM
# ####################
# Metastatic               352
# Primary Tumor             97
# Solid Tissue Normal        2
# Additional Metastatic      1
# Name: Sample Type, dtype: int64
#
#
# ####################
# CPTAC-3
# ####################
# Primary Tumor          1101
# Solid Tissue Normal     579
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-HNSC
# ####################
# Primary Tumor          523
# Solid Tissue Normal     44
# Metastatic               2
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-PCPG
# ####################
# Primary Tumor               179
# Solid Tissue Normal           3
# Additional - New Primary      3
# Metastatic                    2
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-STAD
# ####################
# Primary Tumor          446
# Solid Tissue Normal     45
# Name: Sample Type, dtype: int64
#
#
# ####################
# CGCI-BLGSP
# ####################
# Primary Tumor      85
# Recurrent Tumor     2
# FFPE Scrolls        1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-ESCA
# ####################
# Primary Tumor          186
# Solid Tissue Normal     13
# Metastatic               1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-PRAD
# ####################
# Primary Tumor          498
# Solid Tissue Normal     52
# Metastatic               1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-MESO
# ####################
# Primary Tumor    87
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-GBM
# ####################
# Solid Tissue Normal    5
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-TGCT
# ####################
# Primary Tumor               150
# Additional - New Primary      6
# Name: Sample Type, dtype: int64
#
#
# ####################
# CGCI-HTMCP-CC
# ####################
# Primary Tumor    190
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-BRCA
# ####################
# Primary Tumor          1096
# Solid Tissue Normal     104
# Metastatic                7
# Name: Sample Type, dtype: int64
#
#
# ####################
# CPTAC-2
# ####################
# Primary Tumor    310
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-LAML
# ####################
# Primary Blood Derived Cancer - Peripheral Blood    188
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-UCEC
# ####################
# Primary Tumor          545
# Solid Tissue Normal     33
# Recurrent Tumor          1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TARGET-AML
# ####################
# Primary Blood Derived Cancer - Bone Marrow                 1490
# Primary Blood Derived Cancer - Peripheral Blood             271
# Bone Marrow Normal                                           62
# Recurrent Blood Derived Cancer - Bone Marrow                 42
# Blood Derived Cancer - Bone Marrow, Post-treatment           24
# Cell Lines                                                    6
# Recurrent Blood Derived Cancer - Peripheral Blood             2
# Blood Derived Cancer - Peripheral Blood, Post-treatment       1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-COAD
# ####################
# Primary Tumor          455
# Solid Tissue Normal      8
# Metastatic               1
# Recurrent Tumor          1
# Name: Sample Type, dtype: int64
#
#
# ####################
# REBC-THYR
# ####################
# Primary Tumor          427
# Solid Tissue Normal    397
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-PAAD
# ####################
# Primary Tumor          178
# Solid Tissue Normal      4
# Metastatic               1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-CHOL
# ####################
# Primary Tumor          36
# Solid Tissue Normal     9
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-READ
# ####################
# Primary Tumor          161
# Solid Tissue Normal      3
# Recurrent Tumor          1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-SARC
# ####################
# Primary Tumor      259
# Recurrent Tumor      3
# Metastatic           1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-UCS
# ####################
# Primary Tumor    57
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-UVM
# ####################
# Primary Tumor    80
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-THYM
# ####################
# Primary Tumor          124
# Solid Tissue Normal      2
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-KIRC
# ####################
# Primary Tumor               544
# Solid Tissue Normal          71
# Additional - New Primary      1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-DLBC
# ####################
# Primary Tumor    47
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-LUSC
# ####################
# Primary Tumor          478
# Solid Tissue Normal     45
# Name: Sample Type, dtype: int64
#
#
# ####################
# TARGET-RT
# ####################
# Primary Tumor          66
# Solid Tissue Normal     6
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-LUAD
# ####################
# Primary Tumor          519
# Solid Tissue Normal     46
# Recurrent Tumor          2
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-LIHC
# ####################
# Primary Tumor          372
# Solid Tissue Normal     50
# Recurrent Tumor          3
# Name: Sample Type, dtype: int64
#
#
# ####################
# TCGA-OV
# ####################
# Primary Tumor      490
# Recurrent Tumor      9
# Name: Sample Type, dtype: int64
#
#
# ####################
# TARGET-ALL-P2
# ####################
# Primary Blood Derived Cancer - Bone Marrow           125
# Recurrent Blood Derived Cancer - Bone Marrow          56
# Primary Blood Derived Cancer - Peripheral Blood       48
# Recurrent Blood Derived Cancer - Peripheral Blood      1
# Name: Sample Type, dtype: int64
#
#
# ####################
# TARGET-WT
# ####################
# Primary Tumor          126
# Solid Tissue Normal      6
# Recurrent Tumor          5
# Metastatic               1
# Name: Sample Type, dtype: int64

# %%
thershold = 0 # 是否有正常样本
i = 0

for project in set(df_sample_sheet['Project ID']):
    if sum(df_sample_sheet.loc[df_sample_sheet['Project ID']==project]['Sample Type'].value_counts().index.str.contains('Normal'))>0: # 每个Project ID normal 的
        if df_sample_sheet.loc[df_sample_sheet['Project ID']==project]['Sample Type'].value_counts().loc[df_sample_sheet.loc[df_sample_sheet['Project ID']==project]['Sample Type'].value_counts().index.str.contains('Normal')][0]>thershold:
            i += 1
            print('#'*20)
            print(f'{i} - {project}')
            print('#'*20)
            print(df_sample_sheet.loc[df_sample_sheet['Project ID']==project]['Sample Type'].value_counts())
            print('\n')
# Out:
# ####################
# 1 - TCGA-BLCA
# ####################
# Primary Tumor          417
# Solid Tissue Normal     19
# Metastatic               1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 2 - TCGA-CESC
# ####################
# Primary Tumor          307
# Solid Tissue Normal      3
# Metastatic               2
# Name: Sample Type, dtype: int64
#
#
# ####################
# 3 - TCGA-KIRP
# ####################
# Primary Tumor               291
# Solid Tissue Normal          34
# Additional - New Primary      1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 4 - TCGA-THCA
# ####################
# Primary Tumor          506
# Solid Tissue Normal     59
# Metastatic               8
# Name: Sample Type, dtype: int64
#
#
# ####################
# 5 - TCGA-KICH
# ####################
# Primary Tumor          66
# Solid Tissue Normal    25
# Name: Sample Type, dtype: int64
#
#
# ####################
# 6 - TCGA-SKCM
# ####################
# Metastatic               352
# Primary Tumor             97
# Solid Tissue Normal        2
# Additional Metastatic      1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 7 - CPTAC-3
# ####################
# Primary Tumor          1101
# Solid Tissue Normal     579
# Name: Sample Type, dtype: int64
#
#
# ####################
# 8 - TCGA-HNSC
# ####################
# Primary Tumor          523
# Solid Tissue Normal     44
# Metastatic               2
# Name: Sample Type, dtype: int64
#
#
# ####################
# 9 - TCGA-PCPG
# ####################
# Primary Tumor               179
# Solid Tissue Normal           3
# Additional - New Primary      3
# Metastatic                    2
# Name: Sample Type, dtype: int64
#
#
# ####################
# 10 - TCGA-STAD
# ####################
# Primary Tumor          446
# Solid Tissue Normal     45
# Name: Sample Type, dtype: int64
#
#
# ####################
# 11 - TCGA-ESCA
# ####################
# Primary Tumor          186
# Solid Tissue Normal     13
# Metastatic               1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 12 - TCGA-PRAD
# ####################
# Primary Tumor          498
# Solid Tissue Normal     52
# Metastatic               1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 13 - TCGA-GBM
# ####################
# Solid Tissue Normal    5
# Name: Sample Type, dtype: int64
#
#
# ####################
# 14 - TCGA-BRCA
# ####################
# Primary Tumor          1096
# Solid Tissue Normal     104
# Metastatic                7
# Name: Sample Type, dtype: int64
#
#
# ####################
# 15 - TCGA-UCEC
# ####################
# Primary Tumor          545
# Solid Tissue Normal     33
# Recurrent Tumor          1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 16 - TARGET-AML
# ####################
# Primary Blood Derived Cancer - Bone Marrow                 1490
# Primary Blood Derived Cancer - Peripheral Blood             271
# Bone Marrow Normal                                           62
# Recurrent Blood Derived Cancer - Bone Marrow                 42
# Blood Derived Cancer - Bone Marrow, Post-treatment           24
# Cell Lines                                                    6
# Recurrent Blood Derived Cancer - Peripheral Blood             2
# Blood Derived Cancer - Peripheral Blood, Post-treatment       1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 17 - TCGA-COAD
# ####################
# Primary Tumor          455
# Solid Tissue Normal      8
# Metastatic               1
# Recurrent Tumor          1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 18 - REBC-THYR
# ####################
# Primary Tumor          427
# Solid Tissue Normal    397
# Name: Sample Type, dtype: int64
#
#
# ####################
# 19 - TCGA-PAAD
# ####################
# Primary Tumor          178
# Solid Tissue Normal      4
# Metastatic               1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 20 - TCGA-CHOL
# ####################
# Primary Tumor          36
# Solid Tissue Normal     9
# Name: Sample Type, dtype: int64
#
#
# ####################
# 21 - TCGA-READ
# ####################
# Primary Tumor          161
# Solid Tissue Normal      3
# Recurrent Tumor          1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 22 - TCGA-THYM
# ####################
# Primary Tumor          124
# Solid Tissue Normal      2
# Name: Sample Type, dtype: int64
#
#
# ####################
# 23 - TCGA-KIRC
# ####################
# Primary Tumor               544
# Solid Tissue Normal          71
# Additional - New Primary      1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 24 - TCGA-LUSC
# ####################
# Primary Tumor          478
# Solid Tissue Normal     45
# Name: Sample Type, dtype: int64
#
#
# ####################
# 25 - TARGET-RT
# ####################
# Primary Tumor          66
# Solid Tissue Normal     6
# Name: Sample Type, dtype: int64
#
#
# ####################
# 26 - TCGA-LUAD
# ####################
# Primary Tumor          519
# Solid Tissue Normal     46
# Recurrent Tumor          2
# Name: Sample Type, dtype: int64
#
#
# ####################
# 27 - TCGA-LIHC
# ####################
# Primary Tumor          372
# Solid Tissue Normal     50
# Recurrent Tumor          3
# Name: Sample Type, dtype: int64
#
#
# ####################
# 28 - TARGET-WT
# ####################
# Primary Tumor          126
# Solid Tissue Normal      6
# Recurrent Tumor          5
# Metastatic               1
# Name: Sample Type, dtype: int64

# %%
thershold = 20 # 是否有正常样本
i = 0

for project in set(df_sample_sheet['Project ID']):
    if sum(df_sample_sheet.loc[df_sample_sheet['Project ID']==project]['Sample Type'].value_counts().index.str.contains('Normal'))>0: # 每个Project ID normal 的
        if df_sample_sheet.loc[df_sample_sheet['Project ID']==project]['Sample Type'].value_counts().loc[df_sample_sheet.loc[df_sample_sheet['Project ID']==project]['Sample Type'].value_counts().index.str.contains('Normal')][0]>thershold:
            i += 1
            print('#'*20)
            print(f'{i} - {project}')
            print('#'*20)
            print(df_sample_sheet.loc[df_sample_sheet['Project ID']==project]['Sample Type'].value_counts())
            print('\n')
# Out:
# ####################
# 1 - TCGA-KIRP
# ####################
# Primary Tumor               291
# Solid Tissue Normal          34
# Additional - New Primary      1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 2 - TCGA-THCA
# ####################
# Primary Tumor          506
# Solid Tissue Normal     59
# Metastatic               8
# Name: Sample Type, dtype: int64
#
#
# ####################
# 3 - TCGA-KICH
# ####################
# Primary Tumor          66
# Solid Tissue Normal    25
# Name: Sample Type, dtype: int64
#
#
# ####################
# 4 - CPTAC-3
# ####################
# Primary Tumor          1101
# Solid Tissue Normal     579
# Name: Sample Type, dtype: int64
#
#
# ####################
# 5 - TCGA-HNSC
# ####################
# Primary Tumor          523
# Solid Tissue Normal     44
# Metastatic               2
# Name: Sample Type, dtype: int64
#
#
# ####################
# 6 - TCGA-STAD
# ####################
# Primary Tumor          446
# Solid Tissue Normal     45
# Name: Sample Type, dtype: int64
#
#
# ####################
# 7 - TCGA-PRAD
# ####################
# Primary Tumor          498
# Solid Tissue Normal     52
# Metastatic               1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 8 - TCGA-BRCA
# ####################
# Primary Tumor          1096
# Solid Tissue Normal     104
# Metastatic                7
# Name: Sample Type, dtype: int64
#
#
# ####################
# 9 - TCGA-UCEC
# ####################
# Primary Tumor          545
# Solid Tissue Normal     33
# Recurrent Tumor          1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 10 - TARGET-AML
# ####################
# Primary Blood Derived Cancer - Bone Marrow                 1490
# Primary Blood Derived Cancer - Peripheral Blood             271
# Bone Marrow Normal                                           62
# Recurrent Blood Derived Cancer - Bone Marrow                 42
# Blood Derived Cancer - Bone Marrow, Post-treatment           24
# Cell Lines                                                    6
# Recurrent Blood Derived Cancer - Peripheral Blood             2
# Blood Derived Cancer - Peripheral Blood, Post-treatment       1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 11 - REBC-THYR
# ####################
# Primary Tumor          427
# Solid Tissue Normal    397
# Name: Sample Type, dtype: int64
#
#
# ####################
# 12 - TCGA-KIRC
# ####################
# Primary Tumor               544
# Solid Tissue Normal          71
# Additional - New Primary      1
# Name: Sample Type, dtype: int64
#
#
# ####################
# 13 - TCGA-LUSC
# ####################
# Primary Tumor          478
# Solid Tissue Normal     45
# Name: Sample Type, dtype: int64
#
#
# ####################
# 14 - TCGA-LUAD
# ####################
# Primary Tumor          519
# Solid Tissue Normal     46
# Recurrent Tumor          2
# Name: Sample Type, dtype: int64
#
#
# ####################
# 15 - TCGA-LIHC
# ####################
# Primary Tumor          372
# Solid Tissue Normal     50
# Recurrent Tumor          3
# Name: Sample Type, dtype: int64

# %% [markdown]
# ### 疾病统计

# %% [markdown]
# **hematopoietic and reticuloendothelial systems**
#
# 1. myeloid leukemias
#
#
# TARGET-AML
# 1774
#
# TCGA-LAML
# 188
#
# TARGET-ALL-P3
# 2
#
# 62 + 0 + 0 =62

# %% [markdown]
# **kidney**
#
# 1. adenomas and adenocarcinomas
#
# TCGA-KIRC
# 516
#
# TCGA-KIRP
# 291
#
# CPTAC-3
# 220
#
# TCGA-KICH
# 66
#
# 71 + 34 + 148 + 25 = 278

# %% [markdown]
# **bronchus and lung**
#
# 1. adenomas and adenocarcinomas
#
# TCGA-LUAD
# 477
#
# CPTAC-3
# 229
#
# 46 + 215 = 261
#
# 2. squamous cell neoplasms
#
# TCGA-LUSC
# 478
#
# CPTAC-3
# 108
#
# 45 + 96 = 141

# %% [markdown]
# **breast**
#
# ductal and lobular neoplasms
#
# TCGA-BRCA
# 1035
#
# CPTAC-2
# 103
#
#
# 104 + 0 = 104

# %% [markdown]
# **thyroid gland**
#
# adenomas and adenocarcinomas
#
# TCGA-THCA
# 505
#
# REBC-THYR
# 436
#
# 59 + 397 = 456

# %% [markdown]
# **brain**
#
# gliomas
#
# TCGA-LGG
# 512
#
# CPTAC-3
# 98
#
# 0 + 0 = 0

# %% [markdown]
# **ovary**
#
# cystic, mucinous and serous neoplasms
#
# TCGA-OV
# 489
#
# CPTAC-2
# 71
#
# 0 + 0 = 0

# %% [markdown]
# **colon**
#
# adenomas and adenocarcinomas
#
#
# TCGA-COAD
# 371
#
# CPTAC-2
# 104
#
# TCGA-READ
# 6
#
# 8 + 0 + 3 = 11
